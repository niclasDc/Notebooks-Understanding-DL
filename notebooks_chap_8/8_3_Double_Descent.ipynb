# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# fatal: destination path 'mnist1d' already exists and is not an empty directory.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random

random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale = 2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15:
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_uniform_(layer_in.weight)
        layer_in.bias.data.fill_(0.0)


# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):
    D_i = 40  # Input dimensions
    D_k = n_hidden  # Hidden dimensions
    D_o = 10  # Output dimensions

    # Define a model with two hidden layers
    # And ReLU activations between them
    model = nn.Sequential(
        nn.Linear(D_i, D_k),
        nn.ReLU(),
        nn.Linear(D_k, D_k),
        nn.ReLU(),
        nn.Linear(D_k, D_o))

    # Call the function you just defined
    model.apply(weights_init)

    # Return the model
    return model

# %%
def fit_model(model, data):
    # choose cross entropy loss function (equation 5.24)
    loss_function = torch.nn.CrossEntropyLoss()
    # construct SGD optimizer and initialize learning rate and momentum
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

    x_train = torch.tensor(data['x'].astype('float32'))
    y_train = torch.tensor(data['y'].transpose().astype('long'))
    x_test = torch.tensor(data['x_test'].astype('float32'))
    y_test = torch.tensor(data['y_test'].astype('long'))

    # load the data into a class that creates the batches
    data_loader = DataLoader(TensorDataset(x_train, y_train), batch_size=100, shuffle=True,
                             worker_init_fn=np.random.seed(1))

    # loop over the dataset n_epoch times
    n_epoch = 1000

    for epoch in range(n_epoch):
        # loop over batches
        for i, batch in enumerate(data_loader):
            # retrieve inputs and labels for this batch
            x_batch, y_batch = batch
            # zero the parameter gradients
            optimizer.zero_grad()
            # forward pass -- calculate model output
            pred = model(x_batch)
            # compute the loss
            loss = loss_function(pred, y_batch.long())
            # backward pass
            loss.backward()
            # SGD update
            optimizer.step()

        # Run whole dataset to get statistics -- normally wouldn't do this
        pred_train = model(x_train)
        pred_test = model(x_test)
        _, predicted_train_class = torch.max(pred_train.data, 1)
        _, predicted_test_class = torch.max(pred_test.data, 1)
        errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
        errors_test = 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
        losses_train = loss_function(pred_train, y_train.long()).item()
        losses_test = loss_function(pred_test, y_test.long()).item()
        if epoch % 100 == 0:
            print(
                f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

    return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array(
    [2, 4, 6, 8, 10, 14, 18, 22, 26, 30, 35, 40, 45, 50, 55, 60, 70, 80, 90, 100, 120, 140, 160, 180, 200, 250, 300,
     400])
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden])
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden] = errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302372, train error 89.57,  test loss 2.302804, test error 90.30
# Epoch   100, train loss 2.302218, train error 89.57,  test loss 2.303391, test error 90.30
# Epoch   200, train loss 2.302214, train error 89.57,  test loss 2.303520, test error 90.30
# Epoch   300, train loss 2.302209, train error 89.57,  test loss 2.303467, test error 90.30
# Epoch   400, train loss 2.302214, train error 89.57,  test loss 2.303414, test error 90.30
# Epoch   500, train loss 2.302216, train error 89.57,  test loss 2.303392, test error 90.30
# Epoch   600, train loss 2.302208, train error 89.57,  test loss 2.303447, test error 90.30
# Epoch   700, train loss 2.302218, train error 89.57,  test loss 2.303402, test error 90.30
# Epoch   800, train loss 2.302214, train error 89.57,  test loss 2.303493, test error 90.30
# Epoch   900, train loss 2.302213, train error 89.57,  test loss 2.303496, test error 90.30
# Training model with   4 hidden variables
# Epoch     0, train loss 2.302743, train error 88.65,  test loss 2.303672, test error 89.45
# Epoch   100, train loss 1.805462, train error 66.82,  test loss 1.619916, test error 63.15
# Epoch   200, train loss 1.767568, train error 66.12,  test loss 1.594139, test error 62.85
# Epoch   300, train loss 1.759355, train error 63.95,  test loss 1.595700, test error 62.40
# Epoch   400, train loss 1.753308, train error 64.30,  test loss 1.590003, test error 62.10
# Epoch   500, train loss 1.756865, train error 65.10,  test loss 1.590386, test error 62.92
# Epoch   600, train loss 1.747093, train error 64.12,  test loss 1.589779, test error 62.17
# Epoch   700, train loss 1.750281, train error 64.25,  test loss 1.593114, test error 62.92
# Epoch   800, train loss 1.746230, train error 64.05,  test loss 1.585931, test error 61.55
# Epoch   900, train loss 1.761109, train error 63.90,  test loss 1.599011, test error 62.40
# Training model with   6 hidden variables
# Epoch     0, train loss 2.218972, train error 83.60,  test loss 2.189527, test error 82.72
# Epoch   100, train loss 1.696639, train error 61.05,  test loss 1.517969, test error 59.35
# Epoch   200, train loss 1.652822, train error 58.92,  test loss 1.470691, test error 57.45
# Epoch   300, train loss 1.638242, train error 58.58,  test loss 1.457300, test error 56.88
# Epoch   400, train loss 1.621572, train error 58.05,  test loss 1.449043, test error 56.15
# Epoch   500, train loss 1.614121, train error 57.60,  test loss 1.450581, test error 56.50
# Epoch   600, train loss 1.609135, train error 57.55,  test loss 1.438998, test error 55.97
# Epoch   700, train loss 1.604201, train error 56.88,  test loss 1.439316, test error 56.47
# Epoch   800, train loss 1.597205, train error 56.83,  test loss 1.440323, test error 55.88
# Epoch   900, train loss 1.599314, train error 57.03,  test loss 1.446161, test error 56.15
# Training model with   8 hidden variables
# Epoch     0, train loss 2.249229, train error 83.22,  test loss 2.233313, test error 83.88
# Epoch   100, train loss 1.681087, train error 60.08,  test loss 1.514509, test error 59.38
# Epoch   200, train loss 1.615036, train error 56.53,  test loss 1.443503, test error 54.92
# Epoch   300, train loss 1.586058, train error 54.95,  test loss 1.442025, test error 54.97
# Epoch   400, train loss 1.570271, train error 54.97,  test loss 1.431017, test error 54.35
# Epoch   500, train loss 1.547976, train error 53.17,  test loss 1.373843, test error 50.75
# Epoch   600, train loss 1.531606, train error 51.60,  test loss 1.364859, test error 50.33
# Epoch   700, train loss 1.518025, train error 51.67,  test loss 1.354868, test error 50.20
# Epoch   800, train loss 1.509648, train error 50.83,  test loss 1.359580, test error 50.15
# Epoch   900, train loss 1.515274, train error 51.55,  test loss 1.368691, test error 50.38
# Training model with  10 hidden variables
# Epoch     0, train loss 2.283306, train error 86.07,  test loss 2.276970, test error 85.22
# Epoch   100, train loss 1.581024, train error 54.12,  test loss 1.407435, test error 51.90
# Epoch   200, train loss 1.490626, train error 50.33,  test loss 1.336504, test error 49.28
# Epoch   300, train loss 1.463869, train error 49.03,  test loss 1.328651, test error 49.67
# Epoch   400, train loss 1.450363, train error 48.92,  test loss 1.329990, test error 49.20
# Epoch   500, train loss 1.435423, train error 49.00,  test loss 1.342644, test error 49.85
# Epoch   600, train loss 1.434790, train error 48.78,  test loss 1.344399, test error 49.55
# Epoch   700, train loss 1.428366, train error 48.58,  test loss 1.358255, test error 50.20
# Epoch   800, train loss 1.414175, train error 47.35,  test loss 1.367002, test error 50.40
# Epoch   900, train loss 1.412003, train error 47.38,  test loss 1.362172, test error 49.85
# Training model with  14 hidden variables
# Epoch     0, train loss 2.236491, train error 86.43,  test loss 2.234192, test error 86.20
# Epoch   100, train loss 1.535581, train error 53.28,  test loss 1.437712, test error 54.80
# Epoch   200, train loss 1.445534, train error 49.05,  test loss 1.442414, test error 53.67
# Epoch   300, train loss 1.404758, train error 47.65,  test loss 1.466011, test error 53.25
# Epoch   400, train loss 1.388140, train error 46.97,  test loss 1.472922, test error 53.83
# Epoch   500, train loss 1.380592, train error 47.03,  test loss 1.498166, test error 53.75
# Epoch   600, train loss 1.362065, train error 46.70,  test loss 1.492334, test error 54.12
# Epoch   700, train loss 1.353737, train error 46.47,  test loss 1.517020, test error 54.45
# Epoch   800, train loss 1.341320, train error 45.70,  test loss 1.530446, test error 54.20
# Epoch   900, train loss 1.338331, train error 45.90,  test loss 1.550503, test error 55.08
# Training model with  18 hidden variables
# Epoch     0, train loss 2.254284, train error 83.15,  test loss 2.245299, test error 83.72
# Epoch   100, train loss 1.361854, train error 46.28,  test loss 1.314419, test error 48.75
# Epoch   200, train loss 1.253142, train error 42.22,  test loss 1.332537, test error 48.92
# Epoch   300, train loss 1.200135, train error 39.88,  test loss 1.375482, test error 49.08
# Epoch   400, train loss 1.179482, train error 38.83,  test loss 1.432695, test error 50.47
# Epoch   500, train loss 1.162857, train error 38.90,  test loss 1.477435, test error 50.95
# Epoch   600, train loss 1.157260, train error 38.47,  test loss 1.500314, test error 50.78
# Epoch   700, train loss 1.136709, train error 38.05,  test loss 1.540086, test error 50.97
# Epoch   800, train loss 1.141899, train error 38.88,  test loss 1.576467, test error 51.25
# Epoch   900, train loss 1.129029, train error 37.58,  test loss 1.583415, test error 51.78
# Training model with  22 hidden variables
# Epoch     0, train loss 2.266248, train error 84.75,  test loss 2.263341, test error 84.28
# Epoch   100, train loss 1.370641, train error 44.95,  test loss 1.432596, test error 53.03
# Epoch   200, train loss 1.228373, train error 41.00,  test loss 1.452069, test error 51.60
# Epoch   300, train loss 1.162472, train error 39.55,  test loss 1.515442, test error 52.50
# Epoch   400, train loss 1.117924, train error 37.95,  test loss 1.578343, test error 53.67
# Epoch   500, train loss 1.092177, train error 36.53,  test loss 1.614066, test error 53.12
# Epoch   600, train loss 1.086407, train error 36.72,  test loss 1.672929, test error 53.10
# Epoch   700, train loss 1.071341, train error 37.17,  test loss 1.714863, test error 53.90
# Epoch   800, train loss 1.038535, train error 35.85,  test loss 1.748207, test error 54.47
# Epoch   900, train loss 1.029280, train error 35.35,  test loss 1.793935, test error 54.75
# Training model with  26 hidden variables
# Epoch     0, train loss 2.182200, train error 81.32,  test loss 2.145744, test error 79.60
# Epoch   100, train loss 1.172035, train error 37.60,  test loss 1.280319, test error 47.20
# Epoch   200, train loss 1.043985, train error 34.95,  test loss 1.441599, test error 50.17
# Epoch   300, train loss 0.943670, train error 31.22,  test loss 1.524230, test error 49.12
# Epoch   400, train loss 0.904189, train error 30.28,  test loss 1.653625, test error 50.35
# Epoch   500, train loss 0.864252, train error 28.78,  test loss 1.752181, test error 51.05
# Epoch   600, train loss 0.843701, train error 28.07,  test loss 1.825574, test error 51.75
# Epoch   700, train loss 0.851341, train error 29.40,  test loss 1.889585, test error 52.03
# Epoch   800, train loss 0.830528, train error 28.30,  test loss 1.962660, test error 52.70
# Epoch   900, train loss 0.829232, train error 28.20,  test loss 2.030638, test error 52.47
# Training model with  30 hidden variables
# Epoch     0, train loss 2.101627, train error 78.25,  test loss 2.055769, test error 78.10
# Epoch   100, train loss 1.144770, train error 37.28,  test loss 1.339225, test error 49.25
# Epoch   200, train loss 0.957886, train error 32.18,  test loss 1.512686, test error 50.55
# Epoch   300, train loss 0.877173, train error 29.50,  test loss 1.687768, test error 50.15
# Epoch   400, train loss 0.808936, train error 27.30,  test loss 1.910651, test error 51.95
# Epoch   500, train loss 0.760842, train error 25.68,  test loss 2.078991, test error 53.03
# Epoch   600, train loss 0.763535, train error 26.97,  test loss 2.246003, test error 54.17
# Epoch   700, train loss 0.728444, train error 24.90,  test loss 2.392073, test error 54.38
# Epoch   800, train loss 0.690211, train error 23.90,  test loss 2.513726, test error 53.88
# Epoch   900, train loss 0.700883, train error 24.80,  test loss 2.658691, test error 54.30
# Training model with  35 hidden variables
# Epoch     0, train loss 2.183754, train error 81.47,  test loss 2.143278, test error 80.12
# Epoch   100, train loss 1.053282, train error 34.55,  test loss 1.412057, test error 49.97
# Epoch   200, train loss 0.847118, train error 28.22,  test loss 1.720550, test error 52.58
# Epoch   300, train loss 0.728022, train error 24.68,  test loss 2.025310, test error 53.97
# Epoch   400, train loss 0.664281, train error 21.93,  test loss 2.357124, test error 55.20
# Epoch   500, train loss 0.599192, train error 19.95,  test loss 2.622700, test error 55.55
# Epoch   600, train loss 0.544629, train error 18.30,  test loss 2.953747, test error 56.22
# Epoch   700, train loss 0.533613, train error 17.95,  test loss 3.200004, test error 56.08
# Epoch   800, train loss 0.511486, train error 17.07,  test loss 3.442497, test error 56.78
# Epoch   900, train loss 0.485284, train error 16.62,  test loss 3.715390, test error 57.05
# Training model with  40 hidden variables
# Epoch     0, train loss 2.153351, train error 79.90,  test loss 2.088326, test error 78.05
# Epoch   100, train loss 0.957332, train error 30.45,  test loss 1.434748, test error 49.38
# Epoch   200, train loss 0.687479, train error 22.25,  test loss 1.981891, test error 53.65
# Epoch   300, train loss 0.526325, train error 18.00,  test loss 2.618608, test error 56.12
# Epoch   400, train loss 0.429407, train error 14.15,  test loss 3.360519, test error 57.55
# Epoch   500, train loss 0.375751, train error 12.75,  test loss 4.089701, test error 56.40
# Epoch   600, train loss 0.328068, train error 11.07,  test loss 4.922339, test error 58.55
# Epoch   700, train loss 0.236809, train error 7.35,  test loss 5.654447, test error 58.62
# Epoch   800, train loss 0.270668, train error 9.45,  test loss 6.471558, test error 60.22
# Epoch   900, train loss 0.261462, train error 8.93,  test loss 7.009578, test error 59.30
# Training model with  45 hidden variables
# Epoch     0, train loss 2.118704, train error 78.25,  test loss 2.069397, test error 76.65
# Epoch   100, train loss 0.830960, train error 26.72,  test loss 1.510023, test error 50.90
# Epoch   200, train loss 0.514838, train error 16.10,  test loss 2.168995, test error 52.78
# Epoch   300, train loss 0.347707, train error 11.57,  test loss 3.209301, test error 56.03
# Epoch   400, train loss 0.245562, train error 8.82,  test loss 4.457968, test error 57.42
# Epoch   500, train loss 0.242442, train error 9.15,  test loss 5.688820, test error 57.88
# Epoch   600, train loss 0.168072, train error 5.53,  test loss 6.780082, test error 56.15
# Epoch   700, train loss 0.136500, train error 4.75,  test loss 7.897686, test error 57.53
# Epoch   800, train loss 0.131077, train error 4.28,  test loss 8.792642, test error 57.45
# Epoch   900, train loss 0.010343, train error 0.00,  test loss 9.500624, test error 57.20
# Training model with  50 hidden variables
# Epoch     0, train loss 2.095746, train error 77.75,  test loss 2.047209, test error 77.60
# Epoch   100, train loss 0.763773, train error 24.32,  test loss 1.637910, test error 50.80
# Epoch   200, train loss 0.372513, train error 11.50,  test loss 2.768513, test error 56.28
# Epoch   300, train loss 0.161888, train error 4.12,  test loss 4.446105, test error 57.53
# Epoch   400, train loss 0.033068, train error 0.00,  test loss 6.180357, test error 58.00
# Epoch   500, train loss 0.014065, train error 0.00,  test loss 7.305502, test error 58.35
# Epoch   600, train loss 0.008853, train error 0.00,  test loss 8.013721, test error 58.30
# Epoch   700, train loss 0.006155, train error 0.00,  test loss 8.525453, test error 58.55
# Epoch   800, train loss 0.004751, train error 0.00,  test loss 8.951912, test error 58.75
# Epoch   900, train loss 0.003812, train error 0.00,  test loss 9.300189, test error 58.72
# Training model with  55 hidden variables
# Epoch     0, train loss 2.079757, train error 77.18,  test loss 2.003964, test error 75.82
# Epoch   100, train loss 0.639578, train error 19.88,  test loss 1.712040, test error 52.20
# Epoch   200, train loss 0.224411, train error 5.75,  test loss 3.144366, test error 55.53
# Epoch   300, train loss 0.043584, train error 0.05,  test loss 5.018703, test error 56.62
# Epoch   400, train loss 0.015205, train error 0.00,  test loss 6.134886, test error 57.00
# Epoch   500, train loss 0.008679, train error 0.00,  test loss 6.796659, test error 56.88
# Epoch   600, train loss 0.005987, train error 0.00,  test loss 7.282623, test error 56.80
# Epoch   700, train loss 0.004479, train error 0.00,  test loss 7.653144, test error 56.60
# Epoch   800, train loss 0.003549, train error 0.00,  test loss 7.968107, test error 56.53
# Epoch   900, train loss 0.002935, train error 0.00,  test loss 8.222416, test error 56.65
# Training model with  60 hidden variables
# Epoch     0, train loss 2.075226, train error 78.28,  test loss 2.026201, test error 76.57
# Epoch   100, train loss 0.574893, train error 17.70,  test loss 1.807770, test error 52.33
# Epoch   200, train loss 0.103066, train error 0.70,  test loss 3.513674, test error 54.53
# Epoch   300, train loss 0.019212, train error 0.00,  test loss 4.923772, test error 54.95
# Epoch   400, train loss 0.009325, train error 0.00,  test loss 5.633431, test error 55.08
# Epoch   500, train loss 0.005911, train error 0.00,  test loss 6.098888, test error 55.12
# Epoch   600, train loss 0.004239, train error 0.00,  test loss 6.437147, test error 55.08
# Epoch   700, train loss 0.003259, train error 0.00,  test loss 6.710536, test error 55.22
# Epoch   800, train loss 0.002630, train error 0.00,  test loss 6.933219, test error 55.17
# Epoch   900, train loss 0.002184, train error 0.00,  test loss 7.124759, test error 55.30
# Training model with  70 hidden variables
# Epoch     0, train loss 2.042916, train error 75.35,  test loss 1.979461, test error 74.55
# Epoch   100, train loss 0.361875, train error 8.25,  test loss 1.844671, test error 49.95
# Epoch   200, train loss 0.034376, train error 0.03,  test loss 3.434284, test error 52.55
# Epoch   300, train loss 0.010923, train error 0.00,  test loss 4.190471, test error 52.47
# Epoch   400, train loss 0.006066, train error 0.00,  test loss 4.621428, test error 52.62
# Epoch   500, train loss 0.004056, train error 0.00,  test loss 4.916086, test error 52.88
# Epoch   600, train loss 0.002998, train error 0.00,  test loss 5.140355, test error 52.85
# Epoch   700, train loss 0.002349, train error 0.00,  test loss 5.320370, test error 52.85
# Epoch   800, train loss 0.001918, train error 0.00,  test loss 5.472126, test error 52.95
# Epoch   900, train loss 0.001611, train error 0.00,  test loss 5.602885, test error 52.85
# Training model with  80 hidden variables
# Epoch     0, train loss 2.044412, train error 76.30,  test loss 1.971799, test error 74.82
# Epoch   100, train loss 0.246964, train error 5.20,  test loss 2.094049, test error 51.28
# Epoch   200, train loss 0.019648, train error 0.00,  test loss 3.356001, test error 50.92
# Epoch   300, train loss 0.007858, train error 0.00,  test loss 3.885968, test error 51.10
# Epoch   400, train loss 0.004650, train error 0.00,  test loss 4.201736, test error 50.90
# Epoch   500, train loss 0.003211, train error 0.00,  test loss 4.430583, test error 50.83
# Epoch   600, train loss 0.002421, train error 0.00,  test loss 4.606085, test error 50.70
# Epoch   700, train loss 0.001923, train error 0.00,  test loss 4.751112, test error 50.78
# Epoch   800, train loss 0.001584, train error 0.00,  test loss 4.872088, test error 50.88
# Epoch   900, train loss 0.001341, train error 0.00,  test loss 4.974239, test error 50.85
# Training model with  90 hidden variables
# Epoch     0, train loss 1.994838, train error 73.12,  test loss 1.927570, test error 73.40
# Epoch   100, train loss 0.150391, train error 1.70,  test loss 2.254845, test error 52.50
# Epoch   200, train loss 0.014715, train error 0.00,  test loss 3.350949, test error 53.08
# Epoch   300, train loss 0.006484, train error 0.00,  test loss 3.793501, test error 53.47
# Epoch   400, train loss 0.003963, train error 0.00,  test loss 4.065588, test error 53.12
# Epoch   500, train loss 0.002785, train error 0.00,  test loss 4.259788, test error 53.20
# Epoch   600, train loss 0.002121, train error 0.00,  test loss 4.412220, test error 53.28
# Epoch   700, train loss 0.001697, train error 0.00,  test loss 4.538970, test error 53.40
# Epoch   800, train loss 0.001404, train error 0.00,  test loss 4.643667, test error 53.45
# Epoch   900, train loss 0.001193, train error 0.00,  test loss 4.734402, test error 53.45
# Training model with 100 hidden variables
# Epoch     0, train loss 2.017297, train error 76.00,  test loss 1.937447, test error 75.88
# Epoch   100, train loss 0.100294, train error 0.25,  test loss 2.210504, test error 51.55
# Epoch   200, train loss 0.012114, train error 0.00,  test loss 3.088430, test error 51.97
# Epoch   300, train loss 0.005673, train error 0.00,  test loss 3.453722, test error 52.00
# Epoch   400, train loss 0.003525, train error 0.00,  test loss 3.680094, test error 52.22
# Epoch   500, train loss 0.002501, train error 0.00,  test loss 3.847369, test error 52.30
# Epoch   600, train loss 0.001914, train error 0.00,  test loss 3.979790, test error 52.40
# Epoch   700, train loss 0.001539, train error 0.00,  test loss 4.086805, test error 52.25
# Epoch   800, train loss 0.001279, train error 0.00,  test loss 4.178710, test error 52.33
# Epoch   900, train loss 0.001089, train error 0.00,  test loss 4.258274, test error 52.28
# Training model with 120 hidden variables
# Epoch     0, train loss 1.993936, train error 73.25,  test loss 1.935263, test error 73.25
# Epoch   100, train loss 0.046885, train error 0.00,  test loss 2.300183, test error 51.08
# Epoch   200, train loss 0.009262, train error 0.00,  test loss 2.916934, test error 51.05
# Epoch   300, train loss 0.004622, train error 0.00,  test loss 3.203767, test error 51.10
# Epoch   400, train loss 0.002962, train error 0.00,  test loss 3.387948, test error 50.90
# Epoch   500, train loss 0.002140, train error 0.00,  test loss 3.525589, test error 50.92
# Epoch   600, train loss 0.001654, train error 0.00,  test loss 3.634151, test error 51.00
# Epoch   700, train loss 0.001338, train error 0.00,  test loss 3.724663, test error 51.05
# Epoch   800, train loss 0.001118, train error 0.00,  test loss 3.800972, test error 50.95
# Epoch   900, train loss 0.000956, train error 0.00,  test loss 3.868933, test error 51.03
# Training model with 140 hidden variables
# Epoch     0, train loss 1.963273, train error 72.68,  test loss 1.900859, test error 72.68
# Epoch   100, train loss 0.035914, train error 0.00,  test loss 2.260980, test error 50.67
# Epoch   200, train loss 0.008135, train error 0.00,  test loss 2.757521, test error 50.70
# Epoch   300, train loss 0.004188, train error 0.00,  test loss 2.999152, test error 50.85
# Epoch   400, train loss 0.002728, train error 0.00,  test loss 3.158638, test error 50.88
# Epoch   500, train loss 0.001985, train error 0.00,  test loss 3.276880, test error 51.05
# Epoch   600, train loss 0.001545, train error 0.00,  test loss 3.371871, test error 50.95
# Epoch   700, train loss 0.001255, train error 0.00,  test loss 3.450447, test error 50.97
# Epoch   800, train loss 0.001051, train error 0.00,  test loss 3.518188, test error 51.08
# Epoch   900, train loss 0.000901, train error 0.00,  test loss 3.576623, test error 51.05
# Training model with 160 hidden variables
# Epoch     0, train loss 1.967593, train error 72.97,  test loss 1.898142, test error 74.05
# Epoch   100, train loss 0.029225, train error 0.00,  test loss 2.204263, test error 50.25
# Epoch   200, train loss 0.007291, train error 0.00,  test loss 2.635652, test error 49.97
# Epoch   300, train loss 0.003819, train error 0.00,  test loss 2.844543, test error 49.78
# Epoch   400, train loss 0.002508, train error 0.00,  test loss 2.983378, test error 49.83
# Epoch   500, train loss 0.001836, train error 0.00,  test loss 3.088670, test error 49.75
# Epoch   600, train loss 0.001434, train error 0.00,  test loss 3.172128, test error 49.78
# Epoch   700, train loss 0.001167, train error 0.00,  test loss 3.241548, test error 49.78
# Epoch   800, train loss 0.000979, train error 0.00,  test loss 3.301022, test error 49.83
# Epoch   900, train loss 0.000840, train error 0.00,  test loss 3.353288, test error 49.85
# Training model with 180 hidden variables
# Epoch     0, train loss 1.962490, train error 71.32,  test loss 1.869861, test error 71.95
# Epoch   100, train loss 0.024616, train error 0.00,  test loss 2.097813, test error 48.90
# Epoch   200, train loss 0.006547, train error 0.00,  test loss 2.462775, test error 48.40
# Epoch   300, train loss 0.003510, train error 0.00,  test loss 2.646154, test error 48.17
# Epoch   400, train loss 0.002325, train error 0.00,  test loss 2.770834, test error 48.38
# Epoch   500, train loss 0.001710, train error 0.00,  test loss 2.862110, test error 48.22
# Epoch   600, train loss 0.001339, train error 0.00,  test loss 2.936574, test error 48.25
# Epoch   700, train loss 0.001093, train error 0.00,  test loss 2.998551, test error 48.25
# Epoch   800, train loss 0.000919, train error 0.00,  test loss 3.051539, test error 48.22
# Epoch   900, train loss 0.000790, train error 0.00,  test loss 3.098166, test error 48.22
# Training model with 200 hidden variables
# Epoch     0, train loss 1.930109, train error 69.72,  test loss 1.826604, test error 71.93
# Epoch   100, train loss 0.020457, train error 0.00,  test loss 2.051124, test error 48.40
# Epoch   200, train loss 0.005998, train error 0.00,  test loss 2.366716, test error 48.12
# Epoch   300, train loss 0.003283, train error 0.00,  test loss 2.529795, test error 48.25
# Epoch   400, train loss 0.002197, train error 0.00,  test loss 2.642234, test error 48.22
# Epoch   500, train loss 0.001624, train error 0.00,  test loss 2.726619, test error 48.20
# Epoch   600, train loss 0.001277, train error 0.00,  test loss 2.793796, test error 48.22
# Epoch   700, train loss 0.001046, train error 0.00,  test loss 2.850523, test error 48.17
# Epoch   800, train loss 0.000881, train error 0.00,  test loss 2.899312, test error 48.25
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 2.941902, test error 48.22
# Training model with 250 hidden variables
# Epoch     0, train loss 1.906072, train error 69.70,  test loss 1.837933, test error 70.95
# Epoch   100, train loss 0.016503, train error 0.00,  test loss 1.954321, test error 47.97
# Epoch   200, train loss 0.005250, train error 0.00,  test loss 2.209836, test error 47.90
# Epoch   300, train loss 0.002922, train error 0.00,  test loss 2.349850, test error 47.85
# Epoch   400, train loss 0.001975, train error 0.00,  test loss 2.443336, test error 47.70
# Epoch   500, train loss 0.001470, train error 0.00,  test loss 2.514662, test error 47.70
# Epoch   600, train loss 0.001161, train error 0.00,  test loss 2.572610, test error 47.65
# Epoch   700, train loss 0.000954, train error 0.00,  test loss 2.620680, test error 47.72
# Epoch   800, train loss 0.000806, train error 0.00,  test loss 2.662217, test error 47.72
# Epoch   900, train loss 0.000695, train error 0.00,  test loss 2.698371, test error 47.75
# Training model with 300 hidden variables
# Epoch     0, train loss 1.924278, train error 69.32,  test loss 1.822132, test error 71.50
# Epoch   100, train loss 0.014108, train error 0.00,  test loss 1.881862, test error 47.97
# Epoch   200, train loss 0.004724, train error 0.00,  test loss 2.103585, test error 47.70
# Epoch   300, train loss 0.002684, train error 0.00,  test loss 2.221889, test error 47.75
# Epoch   400, train loss 0.001832, train error 0.00,  test loss 2.302947, test error 47.62
# Epoch   500, train loss 0.001372, train error 0.00,  test loss 2.366523, test error 47.75
# Epoch   600, train loss 0.001087, train error 0.00,  test loss 2.417955, test error 47.67
# Epoch   700, train loss 0.000896, train error 0.00,  test loss 2.460145, test error 47.60
# Epoch   800, train loss 0.000758, train error 0.00,  test loss 2.497119, test error 47.62
# Epoch   900, train loss 0.000655, train error 0.00,  test loss 2.529145, test error 47.58
# Training model with 400 hidden variables
# Epoch     0, train loss 1.857661, train error 67.00,  test loss 1.809679, test error 70.65
# Epoch   100, train loss 0.011512, train error 0.00,  test loss 1.838334, test error 46.72
# Epoch   200, train loss 0.004143, train error 0.00,  test loss 2.027134, test error 46.70
# Epoch   300, train loss 0.002404, train error 0.00,  test loss 2.132090, test error 46.92
# Epoch   400, train loss 0.001657, train error 0.00,  test loss 2.204284, test error 46.78
# Epoch   500, train loss 0.001250, train error 0.00,  test loss 2.259514, test error 46.83
# Epoch   600, train loss 0.000995, train error 0.00,  test loss 2.304494, test error 46.85
# Epoch   700, train loss 0.000823, train error 0.00,  test loss 2.342029, test error 46.80
# Epoch   800, train loss 0.000699, train error 0.00,  test loss 2.374750, test error 46.85
# Epoch   900, train loss 0.000605, train error 0.00,  test loss 2.403231, test error 46.88

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')
ax.set_ylim(0, 100)
ax.set_xlabel('No hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
